# %% [markdown]
# # Rydberg Atom Array — Phase Diagram
#
# > 🚀 **Try Maestro GPU mode with a free trial.**
# > Sign up at **[maestro.qoroquantum.net](https://maestro.qoroquantum.net)** — no credit card required.
#
# ## Why GPU Mode?
#
# A 64-atom phase diagram sweep means **144 MPS simulations** (12×12 grid). Higher bond dimension gives sharper phase boundaries — but MPS cost scales as **O(χ³)**. GPU mode handles the heavy lifting.

# %% [markdown]
# ## Step 0 — Setup
#
# ```bash
# pip install qoro-maestro matplotlib numpy
# ```

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import maestro
from maestro.circuits import QuantumCircuit

from rydberg_demo import (
    create_rydberg_circuit,
    calculate_order_parameter,
    build_z_observables,
)

# %% [markdown]
# ---
#
# ## Phase 1 — Local (CPU, χ=16)
#
# 64 atoms, 8×8 parameter grid, bond dimension χ=16. Fast enough on a laptop to see the Z2 ordered phase emerge.

# %%
# Phase 1 configuration — small grid, low bond dimension
N = 64
GRID = 8
CHI_CPU = 16
V = 5.0
DT = 0.15
STEPS = int(3.0 / DT)

deltas = np.linspace(-1.0, 4.0, GRID)
omegas = np.linspace(0.1, 3.0, GRID)
observables = build_z_observables(N)

print(f"Phase 1: {N} atoms, {GRID}×{GRID} grid, χ={CHI_CPU} (CPU)")
print(f"Total simulations: {GRID * GRID}")

# %%
heatmap_cpu = np.zeros((GRID, GRID))

t0 = time.time()
for i, omega in enumerate(reversed(omegas)):
    for j, delta in enumerate(deltas):
        qc = create_rydberg_circuit(N, omega, delta, V, STEPS, DT)
        res = qc.estimate(
            observables=observables,
            simulator_type=maestro.SimulatorType.QCSim,
            simulation_type=maestro.SimulationType.MatrixProductState,
            max_bond_dimension=CHI_CPU,
        )
        z_expects = res['expectation_values']
        heatmap_cpu[GRID - 1 - i, j] = calculate_order_parameter(z_expects, N)
    print(f"  Row {i+1}/{GRID} done")

cpu_time = time.time() - t0
print(f"\n✅ Phase 1 complete in {cpu_time:.1f}s")

# %%
fig, ax = plt.subplots(figsize=(10, 8))
im = ax.imshow(heatmap_cpu, origin='lower',
               extent=[-1.0, 4.0, 0.1, 3.0],
               cmap='inferno', aspect='auto')
plt.colorbar(im, ax=ax, label='Z2 Staggered Magnetization')
ax.set_xlabel(r'Detuning ($\Delta$)', fontsize=13)
ax.set_ylabel(r'Rabi Frequency ($\Omega$)', fontsize=13)
ax.set_title(f'Phase 1 (CPU): N={N}, χ={CHI_CPU}, {GRID}×{GRID} grid\n'
             f'Completed in {cpu_time:.1f}s', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## Phase 2 — GPU Mode (Higher χ, Finer Grid)
#
# Scale to χ=32 and a 12×12 grid for sharper phase boundaries. GPU handles the O(χ³) cost.
#
# 👉 **[Start your free GPU trial →](https://maestro.qoroquantum.net)**

# %%
GRID_GPU = 12
CHI_GPU = 32

deltas_gpu = np.linspace(-1.0, 4.0, GRID_GPU)
omegas_gpu = np.linspace(0.1, 3.0, GRID_GPU)

print(f"Phase 2: {N} atoms, {GRID_GPU}×{GRID_GPU} grid, χ={CHI_GPU} (GPU)")
print(f"Total simulations: {GRID_GPU * GRID_GPU}")

heatmap_gpu = np.zeros((GRID_GPU, GRID_GPU))

t0 = time.time()
for i, omega in enumerate(reversed(omegas_gpu)):
    for j, delta in enumerate(deltas_gpu):
        qc = create_rydberg_circuit(N, omega, delta, V, STEPS, DT)
        res = qc.estimate(
            observables=observables,
            simulator_type=maestro.SimulatorType.CuQuantum,
            simulation_type=maestro.SimulationType.MatrixProductState,
            max_bond_dimension=CHI_GPU,
        )
        z_expects = res['expectation_values']
        heatmap_gpu[GRID_GPU - 1 - i, j] = calculate_order_parameter(z_expects, N)
    print(f"  Row {i+1}/{GRID_GPU} done")

gpu_time = time.time() - t0
print(f"\n✅ Phase 2 complete in {gpu_time:.1f}s")

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

# Phase 1 result
im1 = axes[0].imshow(heatmap_cpu, origin='lower',
                     extent=[-1.0, 4.0, 0.1, 3.0],
                     cmap='inferno', aspect='auto')
plt.colorbar(im1, ax=axes[0], label='Z2 Order')
axes[0].set_title(f'Phase 1 — CPU χ={CHI_CPU}, {GRID}×{GRID}\n{cpu_time:.1f}s')
axes[0].set_xlabel(r'Detuning ($\Delta$)')
axes[0].set_ylabel(r'Rabi Frequency ($\Omega$)')

# Phase 2 result
im2 = axes[1].imshow(heatmap_gpu, origin='lower',
                     extent=[-1.0, 4.0, 0.1, 3.0],
                     cmap='inferno', aspect='auto')
plt.colorbar(im2, ax=axes[1], label='Z2 Order')
axes[1].set_title(f'Phase 2 — GPU χ={CHI_GPU}, {GRID_GPU}×{GRID_GPU}\n{gpu_time:.1f}s')
axes[1].set_xlabel(r'Detuning ($\Delta$)')
axes[1].set_ylabel(r'Rabi Frequency ($\Omega$)')

plt.tight_layout()
plt.savefig('rydberg_phase_diagram.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"\n⚡ Phase 1 (CPU, χ={CHI_CPU}): {cpu_time:.1f}s for {GRID*GRID} points")
print(f"⚡ Phase 2 (GPU, χ={CHI_GPU}): {gpu_time:.1f}s for {GRID_GPU*GRID_GPU} points")

# %% [markdown]
# ---
#
# ## Ready for Sharper Phase Boundaries?
#
# GPU mode handles the O(χ³) cost of high bond dimension MPS — sharper phase diagrams without the wait.
#
# 👉 **[Start your free GPU trial at maestro.qoroquantum.net](https://maestro.qoroquantum.net)**
