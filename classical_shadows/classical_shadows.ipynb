# %% [markdown]
# # Classical Shadows — Entanglement Detection
#
# > 🚀 **Try Maestro GPU mode with a free trial.**
# > Sign up at **[maestro.qoroquantum.net](https://maestro.qoroquantum.net)** — no credit card required.
#
# ## Why GPU Mode?
#
# The classical shadows protocol needs **hundreds of independent MPS snapshots**. GPU-accelerated MPS cuts per-snapshot time dramatically.

# %% [markdown]
# ## Step 0 — Setup
#
# ```bash
# pip install qoro-maestro matplotlib numpy
# ```

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import maestro

from helpers import (
    Config, get_nn_bonds, site_coords,
    collect_shadow_snapshots, estimate_purity_from_shadows, renyi_s2,
    compute_exact_s2,
)

# %% [markdown]
# ---
#
# ## Phase 1 — Local (CPU, 16 qubits)
#
# 4×4 = 16 qubits with exact ED reference. Proves the shadow protocol works and tracks entanglement growth. Runs in ~2 minutes.

# %%
config_cpu = Config(
    lx=4, ly=4,
    chi_low=16, chi_high=32,
    n_shadows=300,
    trotter_depths=[1, 2, 3, 4, 6, 8, 10],
    use_gpu=False,
)

# Subsystem: two central qubits
cx, cy = config_cpu.lx // 2, config_cpu.ly // 2
subsystem = [cx * config_cpu.ly + cy, cx * config_cpu.ly + (cy + 1)]

print(f"Phase 1: {config_cpu.n_qubits} qubits, {config_cpu.n_shadows} shadows/depth (CPU)")
print(f"Subsystem: qubits {subsystem}")

# %%
bonds = get_nn_bonds(config_cpu.lx, config_cpu.ly)
results_cpu = {'depths': [], 'times': [], 's2': [], 'purity': []}

t0 = time.time()
for depth in config_cpu.trotter_depths:
    t_val = depth * config_cpu.dt
    shadows = collect_shadow_snapshots(config_cpu, depth, bonds, subsystem, verbose=False)
    purity_raw = estimate_purity_from_shadows(shadows)
    s2, purity = renyi_s2(purity_raw, config_cpu.d_A)
    results_cpu['depths'].append(depth)
    results_cpu['times'].append(t_val)
    results_cpu['s2'].append(s2)
    results_cpu['purity'].append(purity)
    print(f"  depth={depth:2d} (t={t_val:.2f})  S₂={s2:.4f}")

cpu_time = time.time() - t0
print(f"\n✅ Phase 1 complete in {cpu_time:.1f}s")

# %%
# Exact ED reference (feasible at 16 qubits)
exact = compute_exact_s2(config_cpu, subsystem)
if exact:
    print(f"Exact ED computed for {len(exact['depths'])} depths")

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(results_cpu['times'], results_cpu['s2'], 'o--',
        color='#7B1FA2', linewidth=2.5, markersize=8,
        label='Classical Shadows (MPS)')
if exact:
    ax.plot(exact['times'], exact['s2'], '-',
            color='#4CAF50', linewidth=2.5, alpha=0.8, label='Exact ED')
ax.set_xlabel('Simulation Time t', fontsize=13)
ax.set_ylabel('2nd Rényi Entropy S₂', fontsize=13)
ax.set_title(f'Phase 1 (CPU): {config_cpu.n_qubits} qubits, {cpu_time:.1f}s', fontsize=14)
ax.legend(fontsize=10)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## Phase 2 — GPU Mode (36 qubits)
#
# 6×6 = 36 qubits — well beyond exact diagonalization. GPU mode accelerates each snapshot.
#
# At 36 qubits, full tomography needs **4³⁶ ≈ 4.7 × 10²¹ measurements**. Classical shadows use just 200.
#
# 👉 **[Start your free GPU trial →](https://maestro.qoroquantum.net)**

# %%
config_gpu = Config(
    lx=6, ly=6,
    chi_low=16, chi_high=64,
    n_shadows=200,
    trotter_depths=[1, 2, 3, 4, 5, 6, 7, 8, 10],
    use_gpu=True,
)

cx2, cy2 = config_gpu.lx // 2, config_gpu.ly // 2
subsystem2 = [cx2 * config_gpu.ly + cy2, cx2 * config_gpu.ly + (cy2 + 1)]

print(f"Phase 2: {config_gpu.n_qubits} qubits, {config_gpu.n_shadows} shadows/depth (GPU)")

bonds2 = get_nn_bonds(config_gpu.lx, config_gpu.ly)
results_gpu = {'depths': [], 'times': [], 's2': [], 'purity': []}

t0 = time.time()
for depth in config_gpu.trotter_depths:
    t_val = depth * config_gpu.dt
    shadows = collect_shadow_snapshots(config_gpu, depth, bonds2, subsystem2, verbose=False)
    purity_raw = estimate_purity_from_shadows(shadows)
    s2, purity = renyi_s2(purity_raw, config_gpu.d_A)
    results_gpu['depths'].append(depth)
    results_gpu['times'].append(t_val)
    results_gpu['s2'].append(s2)
    results_gpu['purity'].append(purity)
    print(f"  depth={depth:2d} (t={t_val:.2f})  S₂={s2:.4f}")

gpu_time = time.time() - t0
print(f"\n✅ Phase 2 complete in {gpu_time:.1f}s")
print(f"\n⚡ Phase 1 (CPU, {config_cpu.n_qubits}q): {cpu_time:.1f}s")
print(f"⚡ Phase 2 (GPU, {config_gpu.n_qubits}q): {gpu_time:.1f}s")

# %% [markdown]
# ---
#
# ## Ready for Larger Systems?
#
# GPU-accelerated MPS makes shadow tomography practical at scale — hundreds of snapshots at 36+ qubits.
#
# 👉 **[Start your free GPU trial at maestro.qoroquantum.net](https://maestro.qoroquantum.net)**
